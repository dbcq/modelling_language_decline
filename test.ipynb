# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from PIL import Image

# cornwall = Image.open("cornwall_mask.tif")
# cornwall = np.array(cornwall, dtype=bool)
f = 'wales_fullsize_country_mask.npy'
d = np.load(f)
plt.imshow(d)

a = [1, 2, 3, 4, 5]
a[::1]
# Out:
# [1, 2, 3, 4, 5]
