# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from PIL import Image

# cornwall = Image.open("cornwall_mask.tif")
# cornwall = np.array(cornwall, dtype=bool)
k = 8000
f = f"/Volumes/Seagate Expansion Drive/OneDrive backup/Durham/Year 4/Project/Masters Project Code/data/Mar/walesICbook5Alpha1.7Beta1.1SigmavarFactor1Deltat0.0004Tmax500.0MEMORY_1_{k}.npy"
d = np.load(f)
plt.imshow(d)

a = [1, 2, 3, 4, 5]
a[::1]
# Out:
# [1, 2, 3, 4, 5]

# %%
from PIL import Image

# cornwall = Image.open("cornwall_mask.tif")
# cornwall = np.array(cornwall, dtype=bool)
k = 220000
f = f"/Volumes/Seagate Expansion Drive/OneDrive backup/Durham/Year 4/Project/Masters Project Code/data/Mar/cornwallPopGaussian10ICriverAlpha1.0Beta1.1SigmavarFactor1Deltat0.0004Tmax500.0_0_/cornwallPopGaussian10ICriverAlpha1.0Beta1.1SigmavarFactor1Deltat0.0004Tmax500.0MEMORY_0_{k}.npy"
d = np.load(f)
plt.imshow(d)

a = [1, 2, 3, 4, 5]
a[::1]
# Out:
# [1, 2, 3, 4, 5]

# %%
real = lambda sim: 1050 + (1800-1050)/264000 * sim
sim = lambda real: (real-1050)*264000/(1800-1050)

# %%
sim(1200)
# Out:
# 52800.0

# %%
print(real(54000))
print(real(122000))
print(real(228000))
# Out:
# 1203.409090909091
# 1396.590909090909
# 1697.7272727272727

# %%
print(sim(1200))
print(sim(1350))
print(sim(1700))
# Out:
# 52800.0
# 105600.0
# 228800.0

# %%
wales_real = lambda sim: 1850 + (4087-1850)/100000 * sim

# %%
print(wales_real(8000))
print(wales_real(28000))
print(wales_real(55000))
# Out:
# 2028.96
# 2476.36
# 3080.3500000000004

# %%
import numpy as np
file = "../assets/cornwall_county_mask.npy"
d = np.load(file)

# %%
cornwallMask = np.load("../assets/cornwall_county_mask.npy").astype(bool)
